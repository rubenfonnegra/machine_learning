# %% [markdown]
# # **Naive Bayes Classifier**

# %% [markdown]
# ```Iris``` dataset description [here](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.load_iris.html#sklearn.datasets.load_iris) \
# ```GaussianNB``` documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.naive_bayes.GaussianNB.html#sklearn.naive_bayes.GaussianNB)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB
from sklearn.datasets import load_iris # Iris dataset

# %%
iris = load_iris() # Load the iris dataset
iris_x = iris.data[:,0:2]  # Features. We'll pick 2
iris_y = iris.target # Labels

# Print shapes
print ( iris_x.shape,iris_y.shape )
# Out:
# (150, 2) (150,)

# %%
#Plot Dispersion
_,ax = plt.subplots(figsize=(5,4))
ax.scatter (iris_x[:,0],iris_x[:,1], c=iris_y,edgecolors='k', cmap='Paired')

# %%
# Instance kNN object
naive_bayes = GaussianNB()

# Training
naive_bayes.fit( iris_x , iris_y )
# Out:
# GaussianNB()

# %%
# # ### Plot decision boundaries
# def Boundaries(NamePred,horizontal, vertical,NValue, Nlabel, width, long):
#   h_min,h_max = horizontal[:,0].min()-0.1, horizontal[:,0].max()+0.1
#   v_min,v_max = vertical[:,1].min()-0.1, vertical[:,1].max()+0.1

#   #cuadricula
#   h_grid, v_grid = np.meshgrid(np.linspace(h_min,h_max,NValue), np.linspace(v_min,v_max,NValue))

#   #calcular predicciones
#   pred_grid = NamePred.predict(np.c_[h_grid.ravel(),v_grid.ravel()])

#   #reshape predicion
#   pred_grid = pred_grid.reshape(h_grid.shape)
#   print(h_grid.shape, v_grid.shape, pred_grid.shape)

#   #Plot Dispersion
#   _, ax =plt.subplots(figsize = (width,long))
#   ax.pcolormesh(h_grid, v_grid, pred_grid, cmap='Paired')
#   ax.scatter(horizontal[:,0],vertical[:,1], c=Nlabel, edgecolors='k', cmap='Paired')
#   ax.set_xticks([])
#   ax.set_yticks([])

# %%
# #Plot decision boundaries
# Boundaries(naive_bayes,iris_x,iris_x,200,iris_y,5,4)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Plot decision boundaries
import sys
sys.path.append('/content/drive/MyDrive/Machine Learning/machine_learning/')
#import
from Tools.fucboundaries import Boundaries

# %%
Boundaries(naive_bayes,iris_x,iris_x,200,iris_y,5,4)
# Out:
# (200, 200) (200, 200) (200, 200)

# %% [markdown]
# ## On real data - Fruits dataset
#
# Download the fruits data [here](https://drive.google.com/file/d/1M8tiAWDZclABJN1Meq9oEHCLJTNyHdpP/view?usp=share_link)

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.naive_bayes import GaussianNB

# %%
#load databaset i don´t used drive
fruit_data = pd.read_csv('/content/fruits_data_ext.csv')
fruit_data.head()
# Out:
#    Unnamed: 0  fruit_label fruit_name fruit_subtype   mass  width  height  \
# 0           0            1      apple  granny_smith  192.0    8.4     7.3
# 1           1            1      apple  granny_smith  180.0    8.0     6.8
# 2           2            1      apple  granny_smith  176.0    7.4     7.2
# 3           3            2   mandarin      mandarin   86.0    6.2     4.7
# 4           4            2   mandarin      mandarin   84.0    6.0     4.6
#
#    color_score
# 0         0.55
# 1         0.59
# 2         0.60
# 3         0.80
# 4         0.79

# %%
fruit_data = fruit_data # Load the fruits dataset
fruits_x = fruit_data[['width', 'height']] # Features. We'll pick 2
fruits_y =  fruit_data['fruit_label'] # Labels

# Convert everything to a np array
fruits_x, fruits_y = np.asarray(fruits_x), np.asarray(fruits_y)

# Print shapes
print (fruits_x.shape, fruits_y.shape)
# Out:
# (177, 2) (177,)

# %%
#Plot Dispersion
_, ax = plt.subplots(figsize=(5,4))
ax.scatter(fruits_x[:,0], fruits_x[:,1], c=fruits_y, edgecolors='k', cmap='Paired')

# %%
# Instance naive_bayes object
naive_bayes = GaussianNB()

# Training
naive_bayes.fit( fruits_x, fruits_y )
# Out:
# GaussianNB()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Plot decision boundaries
import sys
sys.path.append('/content/drive/MyDrive/Machine Learning/machine_learning/')
#import
from Tools.fucboundaries import Boundaries

# %%
Boundaries(naive_bayes,fruits_x,fruits_x,200,fruits_y,5,4)
# Out:
# (200, 200) (200, 200) (200, 200)
