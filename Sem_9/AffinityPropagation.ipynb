# %% [markdown]
# # **Affinity propagation**
#
# Affinity propagation documentation [here](https://scikit-learn.org/stable/modules/generated/sklearn.cluster.AffinityPropagation.html#sklearn.cluster.AffinityPropagation)

# %%
import numpy as np 
import pandas as pd 
from sklearn.cluster import MeanShift 
from sklearn.datasets import make_blobs 
from matplotlib import pyplot as plt

# %%
X_i, _ = make_blobs(n_samples = 150, n_features = 2, cluster_std = 0.60, random_state=2) #, centers = clusters

_, ax = plt.subplots(figsize = (5,5))
_ 
plt.show()

# %%
ms = MeanShift() 

cluster_centers = ms.cluster_centers_

# %%
_, ax = plt.subplots(figsize = (5,5))
_
plt.scatter( _ , _ , marker ='x', color ='r', s = 200, linewidth = 5)

# %% [markdown]
# # **Affinity propagation on real data**

# %%
import numpy as np 
import matplotlib.pyplot as plt
from sklearn.cluster import MeanShift 
from sklearn.datasets import load_iris # Dataset Iris

# %%
_ 


plt.scatter( _ , _ )
print (x.shape, y.shape)

# %%
ms = _ 
centroids = _ 
print(centroids)

# %%
predictions = _

# %%
x_min, x_max = _ , _ 
y_min, y_max = _ , _ 

x_grid, y_grid = np.meshgrid(np.arange( _ , _ , 0.01), np.arange( _ , _ , 0.01))
pred_grid = ms.predict(np.c_[x_grid.ravel(), y_grid.ravel()])
pred_grid = pred_grid.reshape(x_grid.shape)

# %%
plt.figure(1, figsize=(8, 5))
plt.pcolormesh( _ , _ , _ , cmap = plt.cm.Paired)
colores=['blue','cyan','magenta'] #'magenta'

# Plot also the training points
plt.scatter( _ , _ , c=y, edgecolors='k', cmap=plt.cm.Paired)
plt.scatter( _ , _ , marker='D', c="b", s=70)

plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)
plt.xticks(())
plt.yticks(())

# %% [markdown]
# # **Affinity propagation on images**

# %% [markdown]
# Repita la segmentación usando kmeans para las imágenes [image1.jpeg](https://drive.google.com/file/d/1ehjQbNbSLTPOdnzZf5mtcokH-Irb9Hsq/view?usp=sharing) , [image2.png](https://drive.google.com/file/d/1RxivIbgi2eAG6p1myuxQGJs2zhGEsH_4/view?usp=sharing) y [image3.jpg](https://drive.google.com/file/d/1Pc_C9B_vqIxkLFV90RWSlRxRcTN-yKqF/view?usp=sharing)
