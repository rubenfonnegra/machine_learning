# %% [markdown]
# # Let's start on the basics. Variables and arrays

# %% [markdown]
# ### First, import some libraries

# %%
#libreria
import numpy as np
import random as rd

# %%
#create an array of N values
array_1 = np.array([4,8,6,9])
array_1
# Out:
# array([4, 8, 6, 9])

# %%
#create an array of random int value
#array_2 = np.array (np.random.rand(4:5)).astype(int)
array_2 = np.array(rd.sample(range(10,100),4))
print(array_1)
print(array_2)
print(array_1.shape, array_2.shape)
print(array_1 + array_2)
# Out:
# [4 8 6 9]
# [41 46 48 33]
# (4,) (4,)
# [45 54 54 42]

# %%
array_1[3]=70
print(array_1)
# Out:
# [ 4  8  6 70]

# %%
print(array_1*array_2)
# Out:
# [ 164  368  288 2310]

# %% [markdown]
# # Playing with some images! Introduction to OpenCV
#
# Download the image [lena.jpg](https://drive.google.com/file/d/1gH5sJN__2g7f9ndLhLvTECdOBJIGUbg_/view) before getting started!

# %% [markdown]
# ### First, let's mount Google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Import some libraries

# %%
# Import some libraries
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('/content/lena.jpg')
print(type(image))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ### Let's play with the data

# %%
# Printing the image shape (size of the image)
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image.shape
# Out:
# (300, 400, 3)

# %%
# Looking through the image...
# print among image indexes
plt.imshow(image)

# %%
#canal de color obtenga su maximo color
#formaato entero de 8 bits desde 0/255 desde -127 hasta 127
#como hacerlo en c
#for (int i =0 i<300; i+1)
#{
#    for(int j=0; j<400; j+=1)
#    {
#        imagen [i,j,0] = 255;
#    }
#}

# %%
image = cv2.imread("/content/lena.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
image[0: 300, :, 2] =255
plt.imshow(image)

# %%
image = cv2.imread("/content/lena.jpg")
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
lena_face = image[100:200, 150:280, :]
plt.imshow(lena_face)
print(lena_face.shape)
# Out:
# (100, 130, 3)
